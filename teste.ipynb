# %%
import pandas as pd

# %%
df = pd.read_parquet("C:\\Users\\bruno\\Downloads\\person_characters", engine="pyarrow")

# %%
df
# Out:
#           Ano de nascimento Tipo sanguíneo  \
# 0    1974 (24 anos em 1998)             AB
# 1             Desconhecido.  Desconhecido.
# 2             Desconhecido.  Desconhecido.
# 3                      1960              O
# 4             Desconhecido.  Desconhecido.
# ..                      ...            ...
# 158  1962 (não confirmado).              O
# 159           desconhecido.  desconhecido.
# 160           Desconhecido.  Desconhecido.
# 161  1978 (20 anos em 1998)  Desconhecido.
# 162           Desconhecido.  Desconhecido.
#
#                                          Altura  \
# 0                                 Desconhecida.
# 1                                 Desconhecida.
# 2                                 Desconhecida.
# 3    1,83cm (em jogos antigos); 1,90cm (em RE5)
# 4                                2,90m (aprox.)
# ..                                          ...
# 158                                      1,78cm
# 159                               desconhecida.
# ...
